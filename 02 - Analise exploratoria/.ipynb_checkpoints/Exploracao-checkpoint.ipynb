# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Raposo\AppData\Local\Programs\Python\Python311\python.exe

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../dataset/clean/stats_by_player.csv')
df = df[['personName', 'teamName', 'season_year', 'position',
       'fieldGoalsAttempted','threePointersAttempted',
       'freeThrowsAttempted', 'reboundsTotal', 
        'assists', 'steals', 'blocks', 'points', 'minutes']]

features = ['fieldGoalsAttempted','threePointersAttempted','freeThrowsAttempted',
        'reboundsTotal', 'assists', 'steals', 'blocks']

# %%
# Normalizando dados
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
scaled = min_max_scaler.fit_transform(
    df[features].values
)

df[features] = scaled

df
# Out:
#               personName  teamName season_year position  fieldGoalsAttempted  \
# 0               AJ Green     Bucks     2022-23        G             0.132275
# 1               AJ Green     Bucks     2023-24        G             0.129630
# 2             AJ Griffin     Hawks     2022-23        F             0.270879
# 3             AJ Griffin     Hawks     2022-23        G             0.282187
# 4             AJ Griffin     Hawks     2023-24        F             0.106173
# ...                  ...       ...         ...      ...                  ...
# 9931     Zion Williamson  Pelicans     2022-23        F             0.598978
# 9932     Zion Williamson  Pelicans     2023-24        F             0.578836
# 9933        Zoran Dragic      Heat     2014-15        G             0.081481
# 9934        Zoran Dragic      Suns     2014-15        G             0.049383
# 9935  Zydrunas Ilgauskas      Heat     2010-11        C             0.164095
#
#       threePointersAttempted  freeThrowsAttempted  reboundsTotal   assists  \
# 0                   0.227626             0.006015       0.061224  0.036975
# 1                   0.228981             0.017857       0.054422  0.031513
# 2                   0.284161             0.024768       0.098973  0.057670
# 3                   0.245692             0.057644       0.106576  0.064426
# 4                   0.126459             0.007018       0.047619  0.019608
# ...                      ...                  ...            ...       ...
# 9931                0.049712             0.450091       0.331691  0.269777
# 9932                0.019511             0.371429       0.276190  0.295798
# 9933                0.068288             0.010526       0.023810  0.023529
# 9934                0.063230             0.026316       0.023810  0.009804
# 9935                0.001054             0.033626       0.189815  0.021242
#
#         steals    blocks     points    minutes
# 0     0.034286  0.000000   4.400000   9.855714
# 1     0.032143  0.017857   4.500000  10.969345
# 2     0.117647  0.044118   8.666667  19.083660
# 3     0.114286  0.035714   9.380952  20.389683
# 4     0.013333  0.033333   2.466667   8.998889
# ...        ...       ...        ...        ...
# 9931  0.220690  0.137931  26.000000  32.968966
# 9932  0.217143  0.167857  22.871429  31.527619
# 9933  0.040000  0.000000   2.200000   6.178333
# 9934  0.000000  0.000000   1.000000   2.238889
# 9935  0.063889  0.201389   5.000000  15.907870
#
# [9936 rows x 13 columns]

# %%
def mostra_distribuica_features(df):
    plt.figure()
    plt.title(f'Distribuição das caracteristicas dos jogadores da nba')
    for col in features:
        df[col].plot.kde(label=col)
        plt.legend()
    
    plt.figure()
    plt.title(f'Distribuição das caracteristicas da posição G')
    for col in features:
        
        df[df['position'].str.count('G') > 0][col].plot.kde(label=col)
        plt.legend()
    
    plt.figure()
    plt.title(f'Distribuição das caracteristicas da posição F')
    for col in features:
    
        df[df['position'].str.count('F') > 0][col].plot.kde(label=col)
        plt.legend()
    
    plt.figure()
    plt.title(f'Distribuição das caracteristicas da posição C')
    for col in features:
    
        df[df['position'].str.count('C') > 0][col].plot.kde(label=col)
        plt.legend()

mostra_distribuica_features(df)

# %%
def mostra_media_features_em_barra(df):
    df_media_features= df.groupby(by = ['position']).mean(numeric_only=True).reset_index()

    df_media_geral = df.mean(numeric_only=True)
    df_media_geral['position'] = 'Média geral'
    df_media_features = pd.concat([df_media_features, df_media_geral.to_frame().T])
    
    df_media_features.set_index("position")[features].plot.bar()
    plt.title('Média das características por posição')
    

mostra_media_features_em_barra(df)

# %%
# Vendo matriz de correção entre posição e caracteristica
import seaborn as sns

def plot_heatmap(df, tittle):
    features_corr = features + ['position', 'minutes']
    df_corr = df[features_corr].copy()
    
    df_corr['position'] = df_corr['position'].astype('category').cat.codes

    plt.figure
    sns.heatmap(df_corr.corr(), annot=True, fmt=".2f")
    plt.title(tittle)
    plt.show

plot_heatmap(df[df['position'].str.count('G') > 0], "Correlação de caracteristicas de G")
plot_heatmap(df[df['position'].str.count('F') > 0], "Correlação de caracteristicas de F")
plot_heatmap(df[df['position'].str.count('C') > 0], "Correlação de caracteristicas de C")
plot_heatmap(df, "Correlação de caracteristicas Gerais")

# %%
# Percebendo que existem muitos jogadores com as estatisticas muito baixas
# Filtrando jogadores que jogaram em média menos tempo por jogo
df_filter_minutes = df[(df[['minutes']] > 25).all(axis=1)]
mostra_distribuica_features(df_filter_minutes)
