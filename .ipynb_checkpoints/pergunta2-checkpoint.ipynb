# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('C:/repos/ICD/IntroCD/dataset/clean/stats_by_player.csv')
win_minutes_relation = pd.read_csv('C:/repos/ICD/IntroCD/dataset/clean/win_minutes_relation.csv')

df = df.merge(win_minutes_relation.drop(columns = 'minutes'), on = 'personName')

df.columns
# Out:
# Index(['personName', 'teamName', 'season_year', 'position', 'minutes',
#        'fieldGoalsMade', 'fieldGoalsAttempted', 'fieldGoalsPercentage',
#        'threePointersMade', 'threePointersAttempted',
#        'threePointersPercentage', 'freeThrowsMade', 'freeThrowsAttempted',
#        'freeThrowsPercentage', 'reboundsOffensive', 'reboundsDefensive',
#        'reboundsTotal', 'assists', 'steals', 'blocks', 'turnovers',
#        'foulsPersonal', 'points', 'plusMinusPoints', 'W'],
#       dtype='object')

# %%
df_c = df[df['position'].str.count('C') > 0]
df_g = df[df['position'].str.count('G') > 0]
df_f = df[df['position'].str.count('F') > 0]

c_features = ['freeThrowsMade', 'reboundsDefensive', 'reboundsOffensive', 'blocks']

g_features = ['threePointersAttempted', 'assists', 'steals', 'turnovers']

f_features = ['threePointersAttempted', 'reboundsDefensive', 'steals', 'turnovers']

df_c = df_c[c_features + ['W']]

df_g = df_g[g_features + ['W']]

df_f = df_f[f_features + ['W']]

# %%
import statsmodels.api as sm

exog = sm.add_constant(df_c[c_features])
poission_model = sm.GLM(df_c['W'], exog, family=sm.families.Poisson())
result = poission_model.fit()

result.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import statsmodels.api as sm
#       3 exog = sm.add_constant(df_c[c_features])
#       4 poission_model = sm.GLM(df_c['W'], exog, family=sm.families.Poisson())
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\users\raposo\appdata\roaming\python\python313\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from statsmodels) (2.2.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\raposo\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
