# %%
import pandas as pd
from sklearn.svm import OneClassSVM
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\sidne\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:11: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.0)
#   from scipy.sparse import csr_matrix, issparse

# %%
df1 = pd.read_csv('../dataset/raw/regular_season_box_scores_2010_2024_part_1.csv')
df2 = pd.read_csv('../dataset/raw/regular_season_box_scores_2010_2024_part_2.csv')
df3 = pd.read_csv('../dataset/raw/regular_season_box_scores_2010_2024_part_3.csv')
df4 = pd.read_csv('../dataset/raw/regular_season_totals_2010_2024.csv')

df = pd.concat([df1, df2, df3], axis = 0)
def convert_minutes(x):
    if pd.isna(x):
        return None
    try:
        minutes, seconds = map(int, x.split(':'))
        return minutes + seconds / 60
    except:
        return None

df['minutes'] = df['minutes'].apply(convert_minutes)
df['minutes']
# Out:
# 0         4.350000
# 1              NaN
# 2              NaN
# 3              NaN
# 4         9.883333
#             ...
# 141487    0.833333
# 141488         NaN
# 141489         NaN
# 141490    0.650000
# 141491         NaN
# Name: minutes, Length: 424478, dtype: float64

# %%
grouped = df.groupby(by = ['personName', 'gameId']).sum(numeric_only = True).reset_index().drop(columns = ['teamId', 'personId', 'jerseyNum', 'personName'])

# %%
model = OneClassSVM(kernel='rbf', nu=0.1, gamma='scale')
model.fit(grouped)

# %%
scores = model.decision_function(grouped)

labels = model.predict(grouped)

grouped['anomaly_score'] = scores
grouped['anomaly_flag'] = labels

# %%
import matplotlib.pyplot as plt

player = 'LeBron James'
player_df = grouped[df['personName'] == player].sort_values('gameId')

plt.figure(figsize=(12,6))
plt.plot(player_df['gameId'], player_df['minutes'], label='Minutes Played')
plt.scatter(
    player_df[player_df['anomaly_flag'] == -1]['gameId'],
    player_df[player_df['anomaly_flag'] == -1]['minutes'],
    color='red', label='Anomaly', s=100, marker='X'
)
plt.xlabel('Game ID')
plt.ylabel('Minutes Played')
plt.title(f'Minutes Played and Anomalies for {player}')
plt.legend()
plt.show()
